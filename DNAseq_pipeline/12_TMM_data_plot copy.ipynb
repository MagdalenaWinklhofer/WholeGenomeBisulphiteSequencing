# %%
# Import packages 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from scipy import stats
import conorm

# %%
# FUNCTIONS: 

# define a function that transforms the sample names to coherent condition names
def sample_to_condition(sample: str) -> str:
    """Transform individual sample name to coherent condition name."""
    if sample.startswith('N'):
        return 'Normoxia'
    elif sample.startswith('A'):
        return 'Anoxia'
    elif sample.startswith('R'):
        return 'Reoxygenation'
    else: 
        raise ValueError(f"Unknown sample name {sample}")

# %% [markdown]
# # 1 Import DMR and DESeq data

# %%
# read in DMR data (unique gene ids) 
with open('/home/maggy/WholeGenomeBisulphiteSequencing/DNAseq_pipeline/7_match_dmr_to_gene/dmr_within_geneborders_genelist/dmr_unique_geneids.json', 'r') as f:
    dmr_unique_geneids = json.load(f)

# Import DEseq results
# IMPORT raw data 
deg_na = pd.read_csv('/home/maggy/WholeGenomeBisulphiteSequencing/RNAseq_pipeline/11_identify_DEG/comp_anoxia_normoxia.csv', header=0, sep=',').assign(condition='NvsA')
deg_nr = pd.read_csv('/home/maggy/WholeGenomeBisulphiteSequencing/RNAseq_pipeline/11_identify_DEG/comp_reoxygenation_normoxia.csv', header=0, sep=',').assign(condition='NvsR')
deg_ar = pd.read_csv('/home/maggy/WholeGenomeBisulphiteSequencing/RNAseq_pipeline/11_identify_DEG/comp_anoxia_reoxygenation.csv', header=0, sep=',').assign(condition='AvsR')
deg = pd.concat([deg_na, deg_nr, deg_ar])
deg.rename({'Unnamed: 0': 'geneid'},axis=1,  inplace=True)
deg.set_index('geneid', inplace=True)

# %% [markdown]
# # 2 Filter for top 10 genes that were hit by DMR

# %%
# Filter deg data to only keep the rows that are in the dmr data (genes that are hit by DMRs)
dmr_genes=[]

for name, df in dmr_unique_geneids.items(): 
    temp = deg.loc[(deg['condition'] == name) & (deg.index.isin(df))]
    dmr_genes.append(temp)
dmr_genes = pd.concat(dmr_genes)

# %%
# Sort the data by pvalue and keep the top 3 hits for each condition
dmr_genes.sort_values('pvalue', inplace=True)

top_dmr = []

# for each condition filter the top 10 and save in new df 
for condition, data in dmr_genes.groupby('condition'): 
    # filter for unique gene id and keep first 
    temp = data.drop_duplicates(keep='first') #.iloc[:10]
    top_dmr.append(temp)
top_dmr = pd.concat(top_dmr)

# %%
len(top_dmr[['pvalue', 'condition']])
# Out:
# 56

# %% [markdown]
# # 3 Import feature counts data

# %%
# import fetaure cpounts (gene expression data)
expression = pd.read_csv('/home/maggy/WholeGenomeBisulphiteSequencing/RNAseq_pipeline/9_create_GeneCountsMatrix/gene_matrix_count.csv', sep=',', index_col=0)
# reorder the columns of the expression dataframes
# Specify the desired column order
column_order = ['N1', 'N2', 'N3', 'N7', 'A1', 'A2', 'A4', 'A7', 'R2', 'R3', 'R7', 'R8']
# Reorder the dataframe columns
expression = expression.reindex(columns=column_order)
# filter the rows that have as a sum less than 50 counts
expression = expression[(expression.sum(axis=1) >= 50)]

# %%
# data normlization to get TMM data 
expression_tmm = conorm.tmm(expression)

# %%
# filter expression df for all the DMR genes
tmm_dmr = expression_tmm[expression_tmm.index.isin(top_dmr.index)]
# reset index 
tmm_dmr.reset_index(inplace=True)

# %%
len(tmm_dmr)
# Out:
# 50

# %%
# convert from long to short format
tmm_dmr = tmm_dmr.melt(id_vars='Geneid', var_name='sample', value_name='measurement')
# write uniform sample name for each condition 
tmm_dmr['condition'] = tmm_dmr['sample'].apply(sample_to_condition)
tmm_dmr
# Out:
#                Geneid sample  measurement      condition
# 0    ccar_ub01-g23719     N1   882.971976       Normoxia
# 1     ccar_ua02-g1919     N1   240.810539       Normoxia
# 2     ccar_ua02-g2350     N1   163.513329       Normoxia
# 3    ccar_ub03-g26528     N1  4941.075502       Normoxia
# 4    ccar_ub03-g26560     N1   215.044802       Normoxia
# ..                ...    ...          ...            ...
# 595  ccar_ua23-g21428     R8  1896.146019  Reoxygenation
# 596  ccar_ua25-g22490     R8   904.664880  Reoxygenation
# 597  ccar_ua25-g22987     R8     3.946194  Reoxygenation
# 598  ccar_ua25-g23230     R8   100.627936  Reoxygenation
# 599  ccar_ub25-g44776     R8   435.067843  Reoxygenation
#
# [600 rows x 4 columns]

# %% [markdown]
# # 4 Normalization of data

# %%
grouped = tmm_dmr.groupby(['Geneid'])

tmm_norm = []

for gene_id, data in grouped: 
    # calculate the mean for normoxia
    mean = data.loc[data.condition == 'Normoxia', 'measurement']
    if len(mean) == 0: 
        continue
    mean = mean.mean() 
    # calculate the geomean in normoxia 
    geomean = stats.gmean(data.loc[data.condition == 'Normoxia', 'measurement'])
    # write the calculated mean into a new column
    data["norm_average"] = mean
    # Determination of relative deviation
    data["rel_deviation"] = data["measurement"]/mean
    tmm_norm.append(data)
tmm_norm = pd.concat(tmm_norm)
tmm_norm
# Out:
#                Geneid sample  measurement      condition  norm_average
# 1     ccar_ua02-g1919     N1   240.810539       Normoxia    250.713773  \
# 51    ccar_ua02-g1919     N2   300.878397       Normoxia    250.713773
# 101   ccar_ua02-g1919     N3   232.332994       Normoxia    250.713773
# 151   ccar_ua02-g1919     N7   228.833161       Normoxia    250.713773
# 201   ccar_ua02-g1919     A1   110.345942         Anoxia    250.713773
# ..                ...    ...          ...            ...           ...
# 399  ccar_ub25-g44776     A7   463.359524         Anoxia    564.403031
# 449  ccar_ub25-g44776     R2   646.820354  Reoxygenation    564.403031
# 499  ccar_ub25-g44776     R3   578.132551  Reoxygenation    564.403031
# 549  ccar_ub25-g44776     R7   531.645087  Reoxygenation    564.403031
# 599  ccar_ub25-g44776     R8   435.067843  Reoxygenation    564.403031
#
#      rel_deviation
# 1         0.960500
# 51        1.200087
# 101       0.926686
# 151       0.912727
# 201       0.440127
# ..             ...
# 399       0.820973
# 449       1.146026
# 499       1.024326
# 549       0.941960
# 599       0.770846
#
# [600 rows x 6 columns]

# %% [markdown]
# # 5 Significance test

# %% [markdown]
# First we have to test if there is an overall significance between the samples

# %%
from scipy.stats import f_oneway
from scipy.stats import alexandergovern

# test if expression changes are significant 
def stats_test(data: pd.DataFrame):
    grouped = data.groupby('Geneid')
    anova_results = pd.DataFrame(columns=['F', 'p'])
    for geneid, data in grouped: 
        if data['rel_deviation'].isna().all(): 
            continue
        samples=[]
        std_dev=[]
        for _, sample in data.groupby('condition'):
            samples.append(sample['rel_deviation'])
            std_dev.append(sample['rel_deviation'].std())
        if np.all(np.isclose(std_dev, np.mean(std_dev), rtol=0.5)):
            test='anova'
            res = f_oneway(*samples)
        else:
            test= 'alexander-govern'
            res = alexandergovern(*samples)
        F,p = res.statistic, res.pvalue
        anova_results.loc[geneid, 'F'] = F
        anova_results.loc[geneid, 'p'] = p
        anova_results.loc[geneid, 'Test'] = test
    return anova_results

# %%
# apply the defines significance test onto the dataframe 
stat_res = stats_test(tmm_norm)
stat_res
# Out:
#                           F         p              Test
# ccar_ua02-g1919   21.911217  0.000348             anova
# ccar_ua02-g2350   11.833104  0.003024             anova
# ccar_ua05-g5120   11.999092   0.00248  alexander-govern
# ccar_ua05-g5369   16.809514  0.000914             anova
# ccar_ua05-g5816    1.135709  0.363235             anova
# ccar_ua05-g5838    1.394967  0.497837  alexander-govern
# ccar_ua06-g6720    1.143462  0.360995             anova
# ccar_ua10-g10025   2.414948  0.144679             anova
# ccar_ua11-g11397   2.429898  0.296725  alexander-govern
# ccar_ua12-g11671   6.791691  0.015924             anova
# ccar_ua13-g12491   0.587016  0.575934             anova
# ccar_ua14-g13591   5.988387  0.022196             anova
# ccar_ua15-g14205    0.21344  0.811774             anova
# ccar_ua15-g14340   2.291764  0.156868             anova
# ccar_ua15-g14343  12.713935  0.001735  alexander-govern
# ccar_ua15-g14373  17.366181  0.000169  alexander-govern
# ccar_ua15-g14605    7.53186  0.023146  alexander-govern
# ccar_ua16-g15290   1.680396  0.239819             anova
# ccar_ua18-g16750    4.19906  0.051503             anova
# ccar_ua19-g18077   1.517082  0.468349  alexander-govern
# ccar_ua20-g19122   2.188542  0.334784  alexander-govern
# ccar_ua21-g19469   2.519095  0.135267             anova
# ccar_ua22-g20613   1.753339  0.416167  alexander-govern
# ccar_ua23-g21428   2.744568  0.253527  alexander-govern
# ccar_ua25-g22490   1.873595  0.208798             anova
# ccar_ua25-g22987   0.464063  0.642967             anova
# ccar_ua25-g23230   7.400344  0.024719  alexander-govern
# ccar_ub01-g23719    7.82699  0.019971  alexander-govern
# ccar_ub03-g26528   7.498743  0.012116             anova
# ccar_ub03-g26560   6.296396  0.042929  alexander-govern
# ccar_ub04-g26931   6.653296  0.035913  alexander-govern
# ccar_ub05-g28395  20.713267  0.000429             anova
# ccar_ub09-g32065   0.195992  0.825436             anova
# ccar_ub09-g32086   2.153128  0.172123             anova
# ccar_ub10-g32303    0.17204   0.84465             anova
# ccar_ub11-g34027   1.257393  0.329944             anova
# ccar_ub11-g34058  12.678371  0.001766  alexander-govern
# ccar_ub12-g34297   1.571218  0.259845             anova
# ccar_ub12-g34593   4.712746  0.039784             anova
# ccar_ub14-g36242   2.740685  0.117611             anova
# ccar_ub14-g36416   1.712082  0.234363             anova
# ccar_ub15-g36855   8.797708  0.012291  alexander-govern
# ccar_ub19-g40403   2.304302  0.155572             anova
# ccar_ub20-g41333   9.508217  0.006036             anova
# ccar_ub21-g41935   7.108578  0.014059             anova
# ccar_ub22-g43204   2.251806  0.161089             anova
# ccar_ub22-g43219   1.410968  0.293084             anova
# ccar_ub22-g43390  13.655281  0.001083  alexander-govern
# ccar_ub23-g43991   2.460017   0.29229  alexander-govern
# ccar_ub25-g44776    2.03497  0.186578             anova

# %%
# create a filter that checks if the p value is smaller than 0.05 in the anova test
# if that is the case the Geneid can be kept in the data 
# otherwise drop the non significant genes
significant_genes = stat_res[stat_res['p'] < 0.05].index
tmm_norm = tmm_norm[tmm_norm['Geneid'].isin(significant_genes)]

# %% [markdown]
# Now we have established that we have an overall significance, hence we must perform a posthoc test

# %%
from scipy.stats import tukey_hsd
from scipy.stats import mannwhitneyu

# perform post-hoc test 
def posthoc_test(data: pd.DataFrame): 
    grouped = data.groupby('Geneid')
    posthoc_results = pd.DataFrame(index=data['Geneid'].unique())
    for geneid, data in grouped: 
        if data['rel_deviation'].isna().all(): 
            continue
        samples=[]
        groups = list(data.groupby('condition').groups.keys())
        names = []
        for i in groups: 
            for j in groups: 
                names.append('p ' + i+j)
        for name, sample in data.groupby(['condition']):
            samples.append(sample['rel_deviation'])
        test = 'tukey_hsd'
        res = tukey_hsd(*samples)
        posthoc_results.loc[geneid,names] = res.pvalue.flatten()
    return posthoc_results

# %%
post_res = posthoc_test(tmm_norm)
post_res.drop(columns=['p AnoxiaAnoxia', 'p ReoxygenationReoxygenation', 'p NormoxiaNormoxia', 'p AnoxiaNormoxia', 'p ReoxygenationNormoxia', 'p ReoxygenationNormoxia', 'p ReoxygenationAnoxia'], inplace=True)
post_res
# Out:
#                   p AnoxiaReoxygenation  p NormoxiaAnoxia
# ccar_ua02-g1919                0.066935          0.000270  \
# ccar_ua02-g2350                0.004553          0.007529
# ccar_ua05-g5120                0.091312          0.001898
# ccar_ua05-g5369                0.308294          0.000853
# ccar_ua12-g11671               0.020145          0.038071
# ccar_ua14-g13591               0.215219          0.282459
# ccar_ua15-g14343               0.003888          0.017850
# ccar_ua15-g14373               0.025446          0.000552
# ccar_ua15-g14605               0.407398          0.005680
# ccar_ua25-g23230               0.224666          0.071985
# ccar_ub01-g23719               0.029619          0.146609
# ccar_ub03-g26528               0.044465          0.012534
# ccar_ub03-g26560               0.223924          0.053638
# ccar_ub04-g26931               0.123636          0.104011
# ccar_ub05-g28395               0.096406          0.000343
# ccar_ub11-g34058               0.008794          0.003391
# ccar_ub12-g34593               0.046310          0.087973
# ccar_ub15-g36855               0.005723          0.002025
# ccar_ub20-g41333               0.114287          0.004656
# ccar_ub21-g41935               0.036556          0.017132
# ccar_ub22-g43390               0.006481          0.043729
#
#                   p NormoxiaReoxygenation
# ccar_ua02-g1919                  0.008241
# ccar_ua02-g2350                  0.936541
# ccar_ua05-g5120                  0.067293
# ccar_ua05-g5369                  0.007280
# ccar_ua12-g11671                 0.912224
# ccar_ua14-g13591                 0.017767
# ccar_ua15-g14343                 0.577420
# ccar_ua15-g14373                 0.054064
# ccar_ua15-g14605                 0.043799
# ccar_ua25-g23230                 0.735135
# ccar_ub01-g23719                 0.573917
# ccar_ub03-g26528                 0.700205
# ccar_ub03-g26560                 0.625931
# ccar_ub04-g26931                 0.992890
# ccar_ub05-g28395                 0.007877
# ccar_ub11-g34058                 0.792092
# ccar_ub12-g34593                 0.911127
# ccar_ub15-g36855                 0.746596
# ccar_ub20-g41333                 0.144124
# ccar_ub21-g41935                 0.877814
# ccar_ub22-g43390                 0.453909

# %%
# filter the posthoc results for significant genes
# if the p value in one column is sig keep the column 
# if not drop the column
significant_genes = post_res[(post_res <= 0.0455).any(axis=1)].index
tmm_norm = tmm_norm[tmm_norm['Geneid'].isin(significant_genes)]

# %% [markdown]
# # 5 PLOT (Barplot)

# %%
# look up  gene id names to protein names
names = pd.read_csv('/home/maggy/WholeGenomeBisulphiteSequencing/DNAseq_pipeline/13_protein_sequence/blastp_hits_swissprot_genes.txt', sep='\t', index_col=0)
names['symbol'] = names['symbol'].str.split('_').str[0]

# %%
from matplotlib.patches import Patch
# Define the significance list
sig_list = {
    'p AnoxiaReoxygenation': (1, 2),
    'p NormoxiaAnoxia': (0, 1),
    'p NormoxiaReoxygenation': (0, 2)
}

def sig_cat(s):
    if s <= 0.0027:
        return "***"
    if s <= 0.0455:
        return "**"
    return ""

# Set sns color palette to colorblind 
sns.set_theme(palette='Set2', style='whitegrid', context='paper', 
              rc={'axes.labelsize':8, 'xtick.labelsize':8, 'ytick.labelsize':8, 'legend.fontsize':8, 'legend.title_fontsize':8})

# Create a figure with 4x4 subplots
fig, axs = plt.subplots(5, 4, figsize=(17 / 2.54, 14 / 2.54), sharey=True, sharex=False)

# Flatten axs array for easy indexing and letter annotations
axs = axs.flatten()
letters = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# Iterate over each geneid and data group
for idx, (geneid, data) in enumerate(tmm_norm.groupby('Geneid')):
    # Skip non-significant genes
    if np.any(stat_res.loc[geneid, 'Test'] == ''):
        continue

    # If we run out of subplots, stop the loop
    if idx >= len(axs):
        break
    
    ax = axs[idx]
    sns.barplot(data=data, x='condition', y='rel_deviation', capsize=0.1, err_kws={"linewidth": 1.5}, hue='condition', legend=False, ax=ax)
    sns.swarmplot(data=data, x='condition', y='rel_deviation', size=2, ax=ax, dodge=False, hue='condition', legend=False, linewidth=0.7, edgecolor="k", alpha=0.6)
    # significance bars
    x_pos = np.array([p.get_x() for p in ax.patches])
    x_width = np.array([p.get_width() for p in ax.patches])
    x_pos = x_pos + (x_width / 2)
    y, h, col = data['rel_deviation'].max() * 1.04, data['rel_deviation'].max() * 0.01, 'k'

    offset = 0
    sig_info = post_res.loc[geneid, sig_list.keys()]
    sig_info = sig_info.loc[sig_info <= 0.05]
    for name, value in sig_info.items():
        height = np.array([y, y + h, y + h, y]) + offset
        x1, x2 = x_pos[list(sig_list[name])]
        ax.plot([x1, x1, x2, x2], height, lw=0.5, c=col)
        ax.text((x1 + x2) * .5, y + h + offset, sig_cat(value), ha='center', va='bottom', color=col)
        offset += data['rel_deviation'].max() * 0.07
    ax.set_ylim(top=2.5)
    ax.set(xticklabels=[])
    ax.set_xlabel('').set_visible(False)
    ax.set_ylabel('').set_visible(False)
    ax.set_title(names['symbol'].get(geneid, default='unknown'), fontdict={'weight': 'bold'}, fontsize=8)
    # Annotate each subplot with a letter
    ax.text(-0.1, 1.05, letters[idx], transform=ax.transAxes, size=12, weight='bold', color='black')
    # get handles for legend 
    handles, labels = ax.get_legend_handles_labels()
# Hide any unused subplots
for ax in axs[len(tmm_norm.groupby('Geneid')):]:
    ax.axis('off')

# add common x and y label
fig.supylabel('Relative Deviation', ha='center', va='center', rotation='vertical', fontsize=8)

# add legend 
legend_elements = [Patch(color = sns.color_palette('Set2')[0], label = 'Normoxia'), 
                   Patch(color = sns.color_palette('Set2')[1], label = 'Anoxia'), 
                   Patch(color = sns.color_palette('Set2')[2], label = 'Reoxygenation')]
fig.legend(handles = legend_elements, bbox_to_anchor=(0.41, 0.03), loc='lower center', title='Condition')


# Adjust layout to prevent overlap
plt.tight_layout()
# Display the figure
plt.savefig('12_TMM_plot/DMR_expression_tmmpanel.svg')
plt.savefig('12_TMM_plot/DMR_expression_tmmpanel.png', dpi=350)
plt.show()
plt.close()

# %%
# define sig list 
sig_list = {'p AnoxiaReoxygenation': (1,2),
            'p NormoxiaAnoxia': (0,1),
            'p NormoxiaReoxygenation': (0,2)}

def sig_cat(s):
    if s < 0.0027:
        return "***"
    if s < 0.0455:
        return "**"
    
# set sns colorpallete to colorblind 
sns.set_theme(palette='Set2', style = 'whitegrid', context='paper', rc={'axes.labelsize':8, 'xtick.labelsize':8, 'ytick.labelsize':8, 'legend.fontsize':8, 'legend.title_fontsize':8})

for geneid, data in tmm_norm.groupby('Geneid'): 
    if np.any(stat_res.loc[geneid, 'Test'] == ''):
        continue
    # only needed if you want to plot a specific gene!!!
    if geneid != 'ccar_ua02-g2350': 
        continue
    # PLOT
    plt.figure(figsize=(8/2.54, 6/2.54))
    g = sns.barplot(data=data, x='condition', y='rel_deviation', capsize=0.1, err_kws={"linewidth": 1.5}, hue='condition', legend=False)
    sns.swarmplot(data=data, x='condition', y='rel_deviation', size=3, ax=g, 
                  dodge=False, legend=False, linewidth=0.7, edgecolor="k", alpha=0.6, hue='condition')
    # significance bars 
    x_pos = np.array([p.get_x() for p in g.patches])
    x_width = np.array([p.get_width() for p in g.patches])
    x_pos = x_pos + (x_width/2)
    y, h, col = data['rel_deviation'].max() * 1.04, data['rel_deviation'].max() * 0.01, 'k'
    offset=0
    sig_info = post_res.loc[geneid, sig_list.keys()]
    sig_info = sig_info.loc[sig_info <= 0.05]
    for name, value in sig_info.items():
        height= np.array([y, y+h, y+h, y]) + offset
        x1, x2 = x_pos[list(sig_list[name])]
        plt.plot([x1, x1, x2, x2], height, lw=1.2, c=col)
        plt.text((x1+x2)*.5, y+h+offset, sig_cat(value), ha='center', va='bottom', color=col)
        offset += data['rel_deviation'].max() * 0.07    
    plt.title(names['symbol'].get(geneid, default='unknown'), fontdict={'weight': 'bold'}, fontsize=8)
    plt.ylim(top=1.6)
    plt.ylabel('Relative Deviation')
    plt.xlabel('Condition')



    plt.tight_layout()
    plt.savefig(f"12_TMM_plot/{names['symbol'].get(geneid, default='unknown')}_TMM_ccar_normalized.svg")
    plt.show()
    plt.close()
